# %%
import os
import csv
import pandas as pd

import librosa
import librosa.display

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## UrbanSound8k Dataset에 대한 FOLD별 이름 설정

# %%
root = 'D:\GH\Audio\dataset\\UrbanSound8K\\audio\\Total'
root_total = 'D:\GH\Audio\dataset\\UrbanSound8K\\audio\\Total'
csv_root = 'D:\GH\Audio\dataset\\UrbanSound8K\metadata\\UrbanSound8K.csv'

# %%
def Mel_spectrogram(y, sr, log=False):
    ## Mel-Spectogram
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    if log:
        log_S = librosa.power_to_db(S, ref=np.max)
        return log_S
    return S

# %%
### LABEL list 생성
csv_Data = pd.read_csv(csv_root)

### zero-padding for 4seconds
target_length = 88200

# %%
dataset = np.array([])
for idx, file in enumerate(os.listdir(root_total)):
    # print("# path : " + root + '\\' + file)
    filepath = os.path.join(root_total, file)
    y, sr = librosa.load(filepath)

    # zero-padding until 4 seconds
    if y.shape[0] < target_length:
        target_y = np.pad(y, (0, target_length - y.shape[0] - 1), 'constant', constant_values=0)
    elif y.shape[0] > target_length:
        target_y = y[:target_length]
    else:
        target_y = y

    log_S = Mel_spectrogram(target_y, sr, log=True)

    temp_data = csv_Data[csv_Data['slice_file_name'] == file]
    label = temp_data['classID'].values[0]

    if idx == 0:
        dataset = [file, label, log_S]
    else:
        dataset = np.vstack((dataset, [file, label, log_S]))

    print("{}, filename: {}, Done".format(idx, file))

print(dataset.shape)
np.save(root_total + '.npy', dataset)
# Out:
# 0, filename: 100032-3-0-0.wav, Done
# 1, filename: 100263-2-0-117.wav, Done
# c:\Users\angel\anaconda3\envs\tf_dl\lib\site-packages\numpy\core\shape_base.py:121: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# 2, filename: 100263-2-0-121.wav, Done
# 3, filename: 100263-2-0-126.wav, Done
# 4, filename: 100263-2-0-137.wav, Done
# 5, filename: 100263-2-0-143.wav, Done
# 6, filename: 100263-2-0-161.wav, Done
# 7, filename: 100263-2-0-3.wav, Done
# 8, filename: 100263-2-0-36.wav, Done
# 9, filename: 100648-1-0-0.wav, Done
# 10, filename: 100648-1-1-0.wav, Done
# 11, filename: 100648-1-2-0.wav, Done
# 12, filename: 100648-1-3-0.wav, Done
# 13, filename: 100648-1-4-0.wav, Done
# 14, filename: 100652-3-0-0.wav, Done
# 15, filename: 100652-3-0-1.wav, Done
# 16, filename: 100652-3-0-2.wav, Done
# 17, filename: 100652-3-0-3.wav, Done
# 18, filename: 100795-3-0-0.wav, Done
# 19, filename: 100795-3-1-0.wav, Done
# 20, filename: 100795-3-1-1.wav, Done
# 21, filename: 100795-3-1-2.wav, Done
# 22, filename: 100852-0-0-0.wav, Done
# 23, filename: 100852-0-0-1.wav, Done
# 24, filename: 100852-0-0-10.wav, Done
# 25, filename: 100852-0-0-11.wav, Done
# 26, filename: 100852-0-0-12.wav, Done
# 27, filename: 100852-0-0-13.wav, Done
# 28, filename: 100852-0-0-14.wav, Done
# 29, filename: 100852-0-0-15.wav, Done
# 30, filename: 100852-0-0-16.wav, Done
# 31, filename: 100852-0-0-17.wav, Done
# 32, filename: 100852-0-0-18.wav, Done
# 33, filename: 100852-0-0-19.wav, Done
# 34, filename: 100852-0-0-2.wav, Done
# 35, filename: 100852-0-0-20.wav, Done
# 36, filename: 100852-0-0-21.wav, Done
# 37, filename: 100852-0-0-22.wav, Done
# 38, filename: 100852-0-0-23.wav, Done
# 39, filename: 100852-0-0-24.wav, Done
# 40, filename: 100852-0-0-25.wav, Done
# 41, filename: 100852-0-0-26.wav, Done
# 42, filename: 100852-0-0-27.wav, Done
# 43, filename: 100852-0-0-28.wav, Done
# 44, filename: 100852-0-0-29.wav, Done
# 45, filename: 100852-0-0-3.wav, Done
# 46, filename: 100852-0-0-30.wav, Done
# 47, filename: 100852-0-0-4.wav, Done
# 48, filename: 100852-0-0-5.wav, Done
# 49, filename: 100852-0-0-6.wav, Done
# 50, filename: 100852-0-0-7.wav, Done
# 51, filename: 100852-0-0-8.wav, Done
# 52, filename: 100852-0-0-9.wav, Done
# 53, filename: 101281-3-0-0.wav, Done
# 54, filename: 101281-3-0-14.wav, Done
# 55, filename: 101281-3-0-5.wav, Done
# 56, filename: 101382-2-0-10.wav, Done
# 57, filename: 101382-2-0-12.wav, Done
# 58, filename: 101382-2-0-20.wav, Done
# 59, filename: 101382-2-0-21.wav, Done
# 60, filename: 101382-2-0-29.wav, Done
# 61, filename: 101382-2-0-33.wav, Done
# 62, filename: 101382-2-0-42.wav, Done
# 63, filename: 101382-2-0-45.wav, Done
# 64, filename: 101415-3-0-2.wav, Done
# 65, filename: 101415-3-0-3.wav, Done
# 66, filename: 101415-3-0-8.wav, Done
# 67, filename: 101729-0-0-1.wav, Done
# 68, filename: 101729-0-0-11.wav, Done
# 69, filename: 101729-0-0-12.wav, Done
# 70, filename: 101729-0-0-13.wav, Done
# 71, filename: 101729-0-0-14.wav, Done
# 72, filename: 101729-0-0-16.wav, Done
# 73, filename: 101729-0-0-17.wav, Done
# 74, filename: 101729-0-0-18.wav, Done
# 75, filename: 101729-0-0-19.wav, Done
# 76, filename: 101729-0-0-21.wav, Done
# 77, filename: 101729-0-0-22.wav, Done
# 78, filename: 101729-0-0-23.wav, Done
# 79, filename: 101729-0-0-24.wav, Done
# 80, filename: 101729-0-0-26.wav, Done
# 81, filename: 101729-0-0-28.wav, Done
# 82, filename: 101729-0-0-29.wav, Done
# 83, filename: 101729-0-0-3.wav, Done
# 84, filename: 101729-0-0-32.wav, Done
# 85, filename: 101729-0-0-33.wav, Done
# 86, filename: 101729-0-0-36.wav, Done
# 87, filename: 101729-0-0-37.wav, Done
# 88, filename: 101729-0-0-38.wav, Done
# 89, filename: 101729-0-0-39.wav, Done
# 90, filename: 101729-0-0-4.wav, Done
# 91, filename: 101729-0-0-40.wav, Done
# 92, filename: 101729-0-0-6.wav, Done
# 93, filename: 101729-0-0-9.wav, Done
# 94, filename: 101848-9-0-0.wav, Done
# 95, filename: 101848-9-0-1.wav, Done
# 96, filename: 101848-9-0-2.wav, Done
# 97, filename: 101848-9-0-3.wav, Done
# 98, filename: 101848-9-0-8.wav, Done
# 99, filename: 101848-9-0-9.wav, Done
# 100, filename: 102102-3-0-0.wav, Done
# 101, filename: 102103-3-0-0.wav, Done
# 102, filename: 102103-3-1-0.wav, Done
# 103, filename: 102104-3-0-0.wav, Done
# 104, filename: 102105-3-0-0.wav, Done
# 105, filename: 102106-3-0-0.wav, Done
# 106, filename: 102305-6-0-0.wav, Done
# 107, filename: 102547-3-0-2.wav, Done
# 108, filename: 102547-3-0-7.wav, Done
# 109, filename: 102547-3-0-8.wav, Done
# 110, filename: 102842-3-0-1.wav, Done
# 111, filename: 102842-3-1-0.wav, Done
# 112, filename: 102842-3-1-5.wav, Done
# 113, filename: 102842-3-1-6.wav, Done
# 114, filename: 102853-8-0-0.wav, Done
# 115, filename: 102853-8-0-1.wav, Done
# 116, filename: 102853-8-0-2.wav, Done
# 117, filename: 102853-8-0-3.wav, Done
# 118, filename: 102853-8-0-4.wav, Done
# 119, filename: 102853-8-0-5.wav, Done
# 120, filename: 102853-8-0-6.wav, Done
# 121, filename: 102853-8-1-0.wav, Done
# 122, filename: 102857-5-0-0.wav, Done
# 123, filename: 102857-5-0-1.wav, Done
# 124, filename: 102857-5-0-10.wav, Done
# 125, filename: 102857-5-0-11.wav, Done
# 126, filename: 102857-5-0-12.wav, Done
# 127, filename: 102857-5-0-13.wav, Done
# 128, filename: 102857-5-0-14.wav, Done
# 129, filename: 102857-5-0-15.wav, Done
# 130, filename: 102857-5-0-16.wav, Done
# 131, filename: 102857-5-0-17.wav, Done
# 132, filename: 102857-5-0-18.wav, Done
# 133, filename: 102857-5-0-19.wav, Done
# 134, filename: 102857-5-0-2.wav, Done
# 135, filename: 102857-5-0-20.wav, Done
# 136, filename: 102857-5-0-21.wav, Done
# 137, filename: 102857-5-0-22.wav, Done
# 138, filename: 102857-5-0-23.wav, Done
# 139, filename: 102857-5-0-24.wav, Done
# 140, filename: 102857-5-0-25.wav, Done
# 141, filename: 102857-5-0-26.wav, Done
# 142, filename: 102857-5-0-27.wav, Done
# 143, filename: 102857-5-0-28.wav, Done
# 144, filename: 102857-5-0-29.wav, Done
# 145, filename: 102857-5-0-3.wav, Done
# 146, filename: 102857-5-0-30.wav, Done
# 147, filename: 102857-5-0-4.wav, Done
# 148, filename: 102857-5-0-5.wav, Done
# 149, filename: 102857-5-0-6.wav, Done
# 150, filename: 102857-5-0-7.wav, Done
# 151, filename: 102857-5-0-8.wav, Done
# 152, filename: 102857-5-0-9.wav, Done
# 153, filename: 102858-5-0-0.wav, Done
# 154, filename: 102858-5-0-1.wav, Done
# 155, filename: 102871-8-0-0.wav, Done
# 156, filename: 102871-8-0-1.wav, Done
# 157, filename: 102871-8-0-10.wav, Done
# 158, filename: 102871-8-0-11.wav, Done
# 159, filename: 102871-8-0-12.wav, Done
# 160, filename: 102871-8-0-13.wav, Done
# 161, filename: 102871-8-0-14.wav, Done
# 162, filename: 102871-8-0-15.wav, Done
# 163, filename: 102871-8-0-2.wav, Done
# 164, filename: 102871-8-0-3.wav, Done
# 165, filename: 102871-8-0-4.wav, Done
# 166, filename: 102871-8-0-5.wav, Done
# 167, filename: 102871-8-0-6.wav, Done
# 168, filename: 102871-8-0-7.wav, Done
# 169, filename: 102871-8-0-8.wav, Done
# 170, filename: 102871-8-0-9.wav, Done
# 171, filename: 103074-7-0-0.wav, Done
# 172, filename: 103074-7-0-1.wav, Done
# 173, filename: 103074-7-0-2.wav, Done
# 174, filename: 103074-7-1-0.wav, Done
# 175, filename: 103074-7-1-1.wav, Done
# 176, filename: 103074-7-1-2.wav, Done
# 177, filename: 103074-7-1-3.wav, Done
# 178, filename: 103074-7-1-4.wav, Done
# 179, filename: 103074-7-1-5.wav, Done
# 180, filename: 103074-7-1-6.wav, Done
# 181, filename: 103074-7-2-0.wav, Done
# 182, filename: 103074-7-3-0.wav, Done
# 183, filename: 103074-7-3-1.wav, Done
# 184, filename: 103074-7-3-2.wav, Done
# 185, filename: 103074-7-3-3.wav, Done
# 186, filename: 103074-7-4-0.wav, Done
# 187, filename: 103074-7-4-1.wav, Done
# 188, filename: 103074-7-4-2.wav, Done
# 189, filename: 103074-7-4-3.wav, Done
# 190, filename: 103074-7-4-4.wav, Done
# 191, filename: 103074-7-4-5.wav, Done
# 192, filename: 103074-7-4-6.wav, Done
# 193, filename: 103076-3-0-0.wav, Done
# 194, filename: 103076-3-1-0.wav, Done
# 195, filename: 103076-3-2-0.wav, Done
# 196, filename: 103199-4-0-0.wav, Done
# 197, filename: 103199-4-0-3.wav, Done
# 198, filename: 103199-4-0-4.wav, Done
# 199, filename: 103199-4-0-5.wav, Done
# 200, filename: 103199-4-0-6.wav, Done
# 201, filename: 103199-4-1-0.wav, Done
# 202, filename: 103199-4-2-0.wav, Done
# 203, filename: 103199-4-2-1.wav, Done
# 204, filename: 103199-4-2-10.wav, Done
# 205, filename: 103199-4-2-11.wav, Done
# 206, filename: 103199-4-2-2.wav, Done
# 207, filename: 103199-4-2-3.wav, Done
# 208, filename: 103199-4-2-4.wav, Done
# 209, filename: 103199-4-2-5.wav, Done
# 210, filename: 103199-4-2-6.wav, Done
# 211, filename: 103199-4-2-7.wav, Done
# 212, filename: 103199-4-2-8.wav, Done
# 213, filename: 103199-4-2-9.wav, Done
# 214, filename: 103199-4-4-0.wav, Done
# 215, filename: 103199-4-6-0.wav, Done
# 216, filename: 103199-4-7-2.wav, Done
# 217, filename: 103249-5-0-0.wav, Done
# 218, filename: 103249-5-0-1.wav, Done
# 219, filename: 103249-5-0-10.wav, Done
# 220, filename: 103249-5-0-11.wav, Done
# 221, filename: 103249-5-0-12.wav, Done
# 222, filename: 103249-5-0-13.wav, Done
# 223, filename: 103249-5-0-14.wav, Done
# 224, filename: 103249-5-0-15.wav, Done
# 225, filename: 103249-5-0-16.wav, Done
# 226, filename: 103249-5-0-17.wav, Done
# 227, filename: 103249-5-0-18.wav, Done
# 228, filename: 103249-5-0-19.wav, Done
# 229, filename: 103249-5-0-2.wav, Done
# 230, filename: 103249-5-0-3.wav, Done
# 231, filename: 103249-5-0-4.wav, Done
# 232, filename: 103249-5-0-5.wav, Done
# 233, filename: 103249-5-0-6.wav, Done
# 234, filename: 103249-5-0-7.wav, Done
# 235, filename: 103249-5-0-8.wav, Done
# 236, filename: 103249-5-0-9.wav, Done
# 237, filename: 103258-5-0-0.wav, Done
# 238, filename: 103258-5-0-1.wav, Done
# 239, filename: 103258-5-0-10.wav, Done
# 240, filename: 103258-5-0-11.wav, Done
# 241, filename: 103258-5-0-12.wav, Done
# 242, filename: 103258-5-0-13.wav, Done
# 243, filename: 103258-5-0-14.wav, Done
# 244, filename: 103258-5-0-15.wav, Done
# 245, filename: 103258-5-0-16.wav, Done
# 246, filename: 103258-5-0-17.wav, Done
# 247, filename: 103258-5-0-18.wav, Done
# 248, filename: 103258-5-0-19.wav, Done
# 249, filename: 103258-5-0-2.wav, Done
# 250, filename: 103258-5-0-3.wav, Done
# 251, filename: 103258-5-0-4.wav, Done
# 252, filename: 103258-5-0-5.wav, Done
# 253, filename: 103258-5-0-6.wav, Done
# 254, filename: 103258-5-0-7.wav, Done
# 255, filename: 103258-5-0-8.wav, Done
# 256, filename: 103258-5-0-9.wav, Done
# 257, filename: 103357-4-0-0.wav, Done
# 258, filename: 103357-4-0-1.wav, Done
# 259, filename: 103438-5-0-0.wav, Done
# 260, filename: 103438-5-0-1.wav, Done
# 261, filename: 103438-5-0-2.wav, Done
# 262, filename: 104327-2-0-15.wav, Done
# 263, filename: 104327-2-0-19.wav, Done
# 264, filename: 104327-2-0-26.wav, Done
# 265, filename: 104327-2-0-28.wav, Done
# 266, filename: 104327-2-0-3.wav, Done
# 267, filename: 104327-2-0-30.wav, Done
# 268, filename: 104327-2-0-34.wav, Done
# 269, filename: 104327-2-0-4.wav, Done
# 270, filename: 104421-2-0-1.wav, Done
# 271, filename: 104421-2-0-15.wav, Done
# 272, filename: 104421-2-0-20.wav, Done
# 273, filename: 104421-2-0-29.wav, Done
# 274, filename: 104421-2-0-3.wav, Done
# 275, filename: 104421-2-0-5.wav, Done
# 276, filename: 104421-2-0-7.wav, Done
# 277, filename: 104421-2-1-3.wav, Done
# 278, filename: 104625-4-0-15.wav, Done
# 279, filename: 104625-4-0-21.wav, Done
# 280, filename: 104625-4-0-27.wav, Done
# 281, filename: 104625-4-0-29.wav, Done
# 282, filename: 104625-4-0-3.wav, Done
# 283, filename: 104625-4-0-35.wav, Done
# 284, filename: 104625-4-0-40.wav, Done
# 285, filename: 104625-4-0-41.wav, Done
# 286, filename: 104625-4-0-45.wav, Done
# 287, filename: 104625-4-0-48.wav, Done
# 288, filename: 104625-4-0-51.wav, Done
# 289, filename: 104625-4-0-52.wav, Done
# 290, filename: 104625-4-0-53.wav, Done
# 291, filename: 104625-4-0-55.wav, Done
# 292, filename: 104625-4-0-57.wav, Done
# 293, filename: 104625-4-0-66.wav, Done
# 294, filename: 104625-4-1-20.wav, Done
# 295, filename: 104625-4-1-8.wav, Done
# 296, filename: 104817-4-0-0.wav, Done
# 297, filename: 104817-4-0-1.wav, Done
# 298, filename: 104817-4-0-10.wav, Done
# 299, filename: 104817-4-0-11.wav, Done
# 300, filename: 104817-4-0-2.wav, Done
# 301, filename: 104817-4-0-3.wav, Done
# 302, filename: 104817-4-0-4.wav, Done
# 303, filename: 104817-4-0-5.wav, Done
# 304, filename: 104817-4-0-6.wav, Done
# 305, filename: 104817-4-0-7.wav, Done
# 306, filename: 104817-4-0-8.wav, Done
# 307, filename: 104817-4-0-9.wav, Done
# 308, filename: 104998-7-0-5.wav, Done
# 309, filename: 104998-7-10-1.wav, Done
# 310, filename: 104998-7-10-10.wav, Done
# 311, filename: 104998-7-10-13.wav, Done
# 312, filename: 104998-7-10-15.wav, Done
# 313, filename: 104998-7-10-8.wav, Done
# 314, filename: 104998-7-10-9.wav, Done

# %% [markdown]
# ## UrbanSound8k Dataset에 대한 FOLD별 파일이름 및 라벨 설정

# %%
fold_label = np.array([])
for (root, dirs, files) in os.walk(root):
    idx = 0
    print("# root : " + root)

    if root[-1] == str(1):
        csv_fold = csv_Data[csv_Data['fold'] == 1]
    elif root[-1] == str(2):
        csv_fold = csv_Data[csv_Data['fold'] == 2]
    elif root[-1] == str(3):
        csv_fold = csv_Data[csv_Data['fold'] == 3]
    elif root[-1] == str(4):
        csv_fold = csv_Data[csv_Data['fold'] == 4]
    elif root[-1] == str(5):
        csv_fold = csv_Data[csv_Data['fold'] == 5]
    elif root[-1] == str(6):
        csv_fold = csv_Data[csv_Data['fold'] == 6]
    elif root[-1] == str(7):
        csv_fold = csv_Data[csv_Data['fold'] == 7]
    elif root[-1] == str(8):
        csv_fold = csv_Data[csv_Data['fold'] == 8]
    elif root[-1] == str(9):
        csv_fold = csv_Data[csv_Data['fold'] == 9]
    elif root[-1] == str(0):
        csv_fold = csv_Data[csv_Data['fold'] == 10]
    else:
        continue

    if len(dirs) > 0:
        for dir_name in dirs:
            print("dir: " + dir_name)

    if len(files) > 0:
        for file_name in files:
            temp_title = file_name
            print("file: " + file_name)
            temp_data = csv_fold[csv_fold['slice_file_name'] == file_name]
            # print(temp_data)
            if temp_data.shape[0] == 0:
                continue
            label = temp_data['classID'].values[0]
            # print(label)

            if idx == 0:
                fold_label = [file_name, label]
            else:
                fold_label = np.vstack((fold_label, [file_name, label]))
            idx += 1

        print(fold_label.shape)
        print(root)
        np.save(root+'.npy', fold_label)

# %% [markdown]
# ## UrbanSound8k Total Dataset에 대한 FOLD별 학습용 데이터셋, 테스트용 데이터셋 구분

# %%
loaded = np.load(filepath, allow_pickle=True)
pd_loaded = pd.DataFrame(loaded, columns=['filename', 'label', 'data'])

train_dataset = pd.DataFrame(columns = ['filename', 'label', 'data'])
test_dataset = pd.DataFrame(columns = ['filename', 'label', 'data'])

for i in range(1,11):
    name = 'fold' + str(i) + '.npy'
    fold_load = np.load('C:\dataset\\UrbanSound8K\\audio\\' + name, allow_pickle=True)

    for idx, file in enumerate(loaded):
        if idx < fold_load.shape[0]:
            temp_data = pd_loaded[pd_loaded['filename'] == fold_load[idx][0]]
            if temp_data.isnull == False:
                train_dataset = train_dataset.append(temp_data)
            else:
                test_dataset = test_dataset.append(temp_data)
        else:
            temp_data = pd_loaded[pd_loaded['filename'] == file[0]]
            train_dataset = train_dataset.append(temp_data)

        # print(train_dataset)
        # print(test_dataset)
    np_train = train_dataset.to_numpy()
    np_test = test_dataset.to_numpy()

    train_dataset = pd.DataFrame(columns=['filename', 'label', 'data'])
    test_dataset = pd.DataFrame(columns=['filename', 'label', 'data'])

    print(name[:-4] + ' done')
    print(np_train.shape)
    print(np_test.shape)
    np.save('C:\dataset\\UrbanSound8K\\audio\\np_data\\' + name[:-4] + 'train.npy', np_train)
    np.save('C:\dataset\\UrbanSound8K\\audio\\np_data\\' + name[:-4] + 'test.npy', np_test)

# %% [markdown]
# ## UrbanSound8k FOLD1기준 딥러닝 모델 학습을 위한 데이터셋 구성
#
# # Need
# - Total.npy
# - fold1train.npy
# - fold1test.npy

# %%
load_path = 'D:\GH\Audio\dataset\\UrbanSound8K\\audio\\np_data'

'''
loaded = np.load('파일명.npz', allow_pickle=True)
'''

train_path = os.path.join(load_path, 'fold1train.npy')
test_path = os.path.join(load_path, 'fold1test.npy')

train_data = np.load(train_path, allow_pickle=True)
test_data = np.load(test_path, allow_pickle=True)
print(train_data.shape)
print(test_data.shape)

x_train = train_data[:, -1]
y_train = train_data[:, 1]
x_test = test_data[:, -1]
y_test = test_data[:, 1]
print('\n Divide Data')
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

x_train = np.stack(x_train, axis=0)
x_test = np.stack(x_test, axis=0)
print('\n Np Stack')
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

x_train = x_train[...,np.newaxis]
x_test = x_test[...,np.newaxis]
y_train = y_train.reshape((-1,))
y_test = y_test.reshape((-1,))

print('\n Add axis')
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

# 배열의 원소 개수만큼 인덱스 배열을 만든 후
# 무작위로 뒤섞어 줍니다.
idx_train = np.arange(x_train.shape[0])
idx_test = np.arange(x_test.shape[0])
# print(idx)
np.random.shuffle(idx_train)
np.random.shuffle(idx_test)

x_train_shuffle = x_train[idx_train]
y_train_shuffle = y_train[idx_train]
x_test_shuffle = x_test[idx_test]
y_test_shuffle = y_test[idx_test]

print('\n Shuffle Data')
print(x_train_shuffle.shape)
print(y_train_shuffle.shape)
print(x_test_shuffle.shape)
print(y_test_shuffle.shape)
# Out:
# (7859, 3)
# (873, 3)
#
#  Divide Data
# (25,)
# (25, 128, 173)
# (25, 128, 173, 1)
